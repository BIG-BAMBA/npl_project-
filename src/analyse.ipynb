# %%
# %run demo.py
# Out:
# ...
# PARTIE 1 - Prétraitement
# ...
# Le chat mange du poisson.
#   -> ['<s>', 'le', 'chat', 'mange', 'du', 'poisson', '</s>']
# Le chat aime le poisson.
#   -> ['<s>', 'le', 'chat', 'aime', 'le', 'poisson', '</s>']
# Le chien mange de la viande.
#   -> ['<s>', 'le', 'chien', 'mange', 'de', 'la', 'viande', '</s>']
# Le chien aime la viande.
#   -> ['<s>', 'le', 'chien', 'aime', 'la', 'viande', '</s>']
# Le chat joue dans le jardin.
#   -> ['<s>', 'le', 'chat', 'joue', 'dans', 'le', 'jardin', '</s>']
# Le chien joue dans le jardin.
#   -> ['<s>', 'le', 'chien', 'joue', 'dans', 'le', 'jardin', '</s>']
#
# Taille du vocabulaire : 15
# Vocabulaire : ['</s>', '<s>', 'aime', 'chat', 'chien', 'dans', 'de', 'du', 'jardin', 'joue', 'la', 'le', 'mange', 'poisson', 'viande']
# Nombre total de tokens (avec répétitions) : 45
#
# ...
# PARTIE 2 - N-grammes
# ...
#
# Bigrammes et fréquences :
#   ('<s>', 'le') : 6
#   ('le', 'chat') : 3
#   ('le', 'chien') : 3
#   ('poisson', '</s>') : 2
#   ('la', 'viande') : 2
# ...

# %%
from mini_modele_langage import probabilite_bigramme, predire_mot_suivant, generer_phrase, probabilite_phrase

# %%
probabilite_bigramme("le", "chien")
# Out:
# 0.3333333333333333

# %%
predire_mot_suivant("le chien", top_n=3)
# Out:
# [('mange', 0.3333333333333333),
#  ('joue', 0.3333333333333333),
#  ('aime', 0.3333333333333333)]

# %%
generer_phrase()
# Out:
# '<s> le chat mange de la viande </s>'
